# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Sierra Peng: Conceptualization, Data curation, Methodology, Writing - original draft
#
# Dylan Nguyen: Project administration, Software, Visualization, Writing - original draft
#
# Juan Bello:   Analysis, Software, Writing - review & editing
#
# Ellen Kwon: Analysis, Background research, Visualization, Writing - original draft
#
# Russel Wong: Conceptualization, Data curation, Analysis, Methodology

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a statistically significant correlation between ICE arrests and reported rates of rape, murder, robbery, and assault in Texas from 2019 to 2024?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Immigration and Customs Enforcement (ICE) is a federal agency acting under the Department of Homeland Security. The main responsibilities of ICE include enforcing immigration law, preventing terrorism, and stopping illegal movement of people and goods within the United States.
#
# The motivation for exploring our topic lies in the dramatic increase in funding that ICE has received with the One Big Beautiful Bill Act. Prior to the passage of the One Big Beautiful Bill Act, ICE received about 10 billion dollars in budget per year. After passing, funding increased to 85 billion dollars. With the marked uptick in funding, activity, and media coverage, ICE has become a hotly contested topic for the American public in recent months, especially with notable incidents involving Renee Good and Alex Pretti. We will attempt to gain a better understanding of the efficacy of ICE on reducing violent and property crime.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1)
#
# An article published in the The Journal of Law & Economics by Thomas J. Miles and Adam B. Cox examined the relationship between immigration enforcement and local US crime rates. The research specifically investigates the effect of the Secure Communities program. The Secure Communities program uses fingerprint-sharing between local law enforcement and federal immigration authorities to facilitate detention and removal of noncitizens. This is not a direct correlate to ICE, however, it may serve as a proxy to understand whether or not strict enforcement of immigration policy reduces crime. The conclusion of the study showed that the Secure Communities program led to hundreds of thousands of detentions, but did not reduce crime-rates as expected.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# The article Immigration and Customs Enforcement Raids the Pillar of a Community: Student Achievement, Absenteeism, and Mobility Following a Large Worksite Enforcement Operation in North Texas looks at the effects that ICE had through various time extents. It serves as a point of interest as to why Texas was chosen for this project, as well as a way to question what sort of empirical and statistical impact ICE had.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3)
#
# Of all states affected by ICE, Texas stands out in the number and scale of people detained. According to data from the Transactional Records Access Clearinghouse (TRAC) Immigration, there are 18,684 people in detention (as of January 22, 2026), which makes Texas the state with the most ICE detainees, followed by Louisiana, 8,207 people, and California, 6,422. Geographically, Texas shares the longest border between the U.S. and Mexico, stretching 382 miles, with more than 40 border security stations across 5 sectors. The sheer size of the border and affiliated border control stations are key in understanding the subsequent size of detainees in Texas. While Texas holds the greatest number of detainees, it is critical to understand that detention location is not the same as arrest location. Texas maintains some of the largest ICE detention centers in the country, where those arrested both in and out of Texas may be placed into. We have chosen to examine ICE arrest data in the state of Texas, rather than the number of detainees. <a name="cite_ref-4"></a>[<sup>4,</sup>](#cite_note-4)<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Chappell, Bill. “How ICE Grew to Be the Highest-Funded U.S. Law Enforcement Agency.” NPR, 21 Jan. 2026, www.npr.org/2026/01/21/nx-s1-5674887/ice-budget-funding-congress-trump.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Miles, T. J., & Cox, A. B. (2014). Does Immigration Enforcement Reduce Crime? Evidence from Secure Communities. The Journal of Law and Economics, 57(4), 937–973. https://doi.org/10.1086/680935
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) J. Jacob Kirksey, and Carolyn Sattin-Bajaj. “Immigration and Customs Enforcement Raids the Pillar of a Community: Student Achievement, Absenteeism, and Mobility Following a Large Worksite Enforcement Operation in North Texas.” American Behavioral Scientist, 28 Nov. 2023, https://doi.org/10.1177/00027642231215992.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)U.S. Customs and Border Protection. (2025, n.d.). Border Patrol sectors. U.S. Department of Homeland Security. https://www.cbp.gov/border-security/along-us-borders/border-patrol-sectors
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)Transactional Records Access Clearinghouse. (2026). Immigration Quick Facts. https://tracreports.org/immigration/quickfacts/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# There will be no statistically significant relationship between the level of ICE arrests and rates of rape, murder, robbery, and assault in the state of Texas from 2019 to 2024. This hypothesis is based on the study on the Secure Communities program which did not reduce crime rates despite detaining hundreds of thousands of immigrants.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# ## **Dataset #1**
# **Dataset Name:** ICE Administrative Arrests
# **Link to the dataset:** https://deportationdata.org/data/ice.html#historical-data-archive
# **Number of observations:** 89,848 (Texas)
# **Number of variables:** 23
#
# ### Descriptions of Variables
#   - We will primarily be looking at the apprehension date and time made by an ICE officer. These two variables can tell us which area a crime was happening and the time of someones aprehension. We are tracking this throughout 2019-2024.
#
# ### Shortcomings with respect to the project
# The ICE dataset does not give precise arrest locations. It is under a broad area or a landmark that are used inconsistently in the report. Being able to localize arrest location would help us have finer tracking when it comes to crime rate in certain areas and trying to connect it with arrests happening in similar areas.
#
#
# ## **Dataset #2**
# **Dataset Name:** Texas Crime Reports
# **Link to the dataset:** https://cde.ucr.cjis.gov/LATEST/webapp/#/pages/downloads
# **Number of observations:** 966799 (2019)
# **Number of variables:** 8
#
# ### Descriptions of Variables
#   - We will be looking at the number of violent offense types of crimes happening from 2019-2024. Our main variable will be how many offense types, more specifically violent offenses, happened that year. The crimes we tracked were counts of Rape, Murder and Nonnegligent Manslaughters, Robberies, and Aggravated Assaults.
#
# ### Shortcomings with respect to the project
# Our main concern is that our data is aggregated at the state level and is not broken down by county or city. Because of this, we cannot examine regional variation within Texas. Any localized increases or decreases in violent crime may be hidden when looking at statewide totals. We are looking at pre and post Covid data. Irregularities wit policing patterns and crime might be common.
#
# Our goal is to examine trends over time and determine whether increases or decreases in ICE activity are linked to changes in violent crime levels.

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851831800585', 'filename':'ice_2018-2019.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851835191968', 'filename':'ice_2019-2020.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851833034596', 'filename':'ice_2020-2021.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851830686826', 'filename':'ice_2021-2022.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851836416108', 'filename':'ice_2022-2023.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851836311169', 'filename':'ice_2023-2024.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_2112094399060', 'filename':'ice_2024-2025.xlsx'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/ice_arrests')

# %%
import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data
datafiles_crime = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1vUrRUCDvJfnjMEV2k3jT-jD9QH6Ax1pz', 'filename':'texas_offenses_2019.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1-iGlPAfnkI9qUClc9H-a1ySWY-RYssAn', 'filename':'texas_offenses_2020.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1SPwSRvfHo7P_n1-VTypUk2qns6lJNUMB', 'filename':'texas_offenses_2021.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1YA20c8y5EfLCh3DdIoPPUpoNHUm6f9G8', 'filename':'texas_offenses_2022.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1q6mbYv2bzWPiUcX-12HkaA7m6D-FDkbT', 'filename':'texas_offenses_2023.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1nirFhfidk26ksytkGnWUBwSMWehyKK9P', 'filename':'texas_offenses_2024.csv'},
]

get_data.get_raw(datafiles_crime,destination_directory='data/00-raw/texas_crime_reports')

# %%
import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data
datafiles_crime_monthly = [
    { 'url': 'https://drive.google.com/uc?export=download&id=12YQG8PDsgGaWl6T5xq94-rM0zdlzxXDy', 'filename':'texas_offenses_monthly.csv'}
]

get_data.get_raw(datafiles_crime_monthly,destination_directory='data/00-raw/texas_crime_reports_monthly')

# %% [markdown]
# ### ICE Administrative Arrests 2018-2024
#
# The ICE Administrative Arrest dataset primarily provides information about immigration-related apprehensions conducted by ICE. For this project, the key metric we use is Apprehension Date and Time. This variable records the specific date (and sometimes time) that an administrative arrest occurred. The unit of measurement is calendar time (year, month, day, and occasionally hour/minute). From this variable, we extract the year of each arrest in order to aggregate total ICE administrative arrests per year from 2019 through 2024

# %%
import pandas as pd

# %%
def clean_ice_df(ice_df):
    # fix column names
    ice_df.columns = ice_df.iloc[3]

    # remove unecessary rows from beginning
    ice_df_drop = ice_df.iloc[4:].reset_index(drop=True)

    # keep only date and AOR columns
    ice_df_drop = ice_df_drop[['Apprehension AOR', 'Apprehension Date And Time', 'Most Serious Crime Class']]

    # keep only Texas arrests
    texas_aor = ['Dallas Area of Responsibility', 
             'El Paso Area of Responsibility', 
             'Harlingen Area of Responsibility', 
             'Houston Area of Responsibility', 
             'San Antonio Area of Responsibility']
    ice_df_texas = ice_df_drop[ice_df_drop['Apprehension AOR'].isin(texas_aor)]

    ice_df_texas['Most Serious Crime Class'] = ice_df_texas['Most Serious Crime Class'].fillna('Not Reported')

    #filter for years 2019-2024
    ice_df_texas['Apprehension Date And Time'] = pd.to_datetime(
    ice_df_texas['Apprehension Date And Time'], errors='coerce')
    ice_df_2019_2024 = ice_df_texas[
    ice_df_texas['Apprehension Date And Time'].dt.year.between(2019, 2024)]

    #remove any nan rows
    ice_df_clean = ice_df_2019_2024.dropna()
    ice_df_clean = ice_df_clean.drop_duplicates().reset_index(drop=True)
    
    return ice_df_clean

# %%
# years of each data file
years = [[2018, 2019],
 [2019, 2020],
 [2020, 2021],
 [2021, 2022],
 [2022, 2023],
 [2023, 2024],
 [2024, 2025]]

clean_dfs = []  # list to store cleaned dataframes

for yr in years:
    year_start, year_end = yr

    print(f'cleaning the data for {year_start}-{year_end}...')
    # load data and clean it 
    ice_df = pd.read_excel(f'data/00-raw/ice_arrests/ice_{year_start}-{year_end}.xlsx')
    clean_ice = clean_ice_df(ice_df)

    # append to the list
    clean_dfs.append(clean_ice)

# concatenate all cleaned dataframes into one
final_clean_ice = pd.concat(clean_dfs, ignore_index=True)

# %%
# save final clean data 
final_clean_ice.to_csv('data/02-processed/ice_arrests_clean.csv', index=False)

# %%
# Reload the saved clean ICE data
final_clean_ice = pd.read_csv('data/02-processed/ice_arrests_clean.csv')

display(final_clean_ice.head())
print("Shape:", final_clean_ice.shape)
print("\nData Types:\n", final_clean_ice.dtypes)
print("\nNull Counts:\n", final_clean_ice.isnull().sum())
print("\nNull Proportions:\n", final_clean_ice.isnull().mean().round(4))
print("\nArrests by Year:\n", pd.to_datetime(final_clean_ice['Apprehension Date And Time']).dt.year.value_counts().sort_index())
print("\nArrests by Texas AOR:\n", final_clean_ice['Apprehension AOR'].value_counts())
print("\nMost Serious Crime Class:\n", final_clean_ice['Most Serious Crime Class'].value_counts())
print("\nNumber of duplicate rows:", final_clean_ice.duplicated().sum(), "| Therefore each row represents a single arrest")

missing_apprehensions = final_clean_ice['Apprehension Date And Time'].isna().sum()
print("\nRows missing apprehension timestamp:", missing_apprehensions)

parsed_dates = pd.to_datetime(
    final_clean_ice['Apprehension Date And Time'],
    errors='coerce'
)

invalid_dates = parsed_dates.isna().sum()
print("Invalid apprehension timestamps:", invalid_dates)

print("Total rows:", len(final_clean_ice))
print("Total valid apprehension timestamps:", parsed_dates.notna().sum())
# Out:
#                 Apprehension AOR Apprehension Date And Time  \
# 0  Dallas Area of Responsibility        2019-03-07 08:22:00
# 1  Dallas Area of Responsibility        2019-01-07 10:32:00
# 2  Dallas Area of Responsibility        2019-01-07 10:22:00
# 3  Dallas Area of Responsibility        2019-05-02 09:38:00
# 4  Dallas Area of Responsibility        2019-05-19 09:43:00
#
#   Most Serious Crime Class
# 0              Misdemeanor
# 1              Misdemeanor
# 2              Misdemeanor
# 3                   Felony
# 4              Misdemeanor
# Shape: (199617, 3)
#
# Data Types:
#  Apprehension AOR              object
# Apprehension Date And Time    object
# Most Serious Crime Class      object
# dtype: object
#
# Null Counts:
#  Apprehension AOR              0
# Apprehension Date And Time    0
# Most Serious Crime Class      0
# dtype: int64
#
# Null Proportions:
#  Apprehension AOR              0.0
# Apprehension Date And Time    0.0
# Most Serious Crime Class      0.0
# ...

# %% [markdown]
# ## Texas Crime Report Offences
#
# The Texas Crime Reports dataset provides statewide arrest data collected through the FBI’s Uniform Crime Reporting (UCR) system. For this project, the primary metric we are using is the number of violent offense arrests per year from 2019 through 2024. Violent offenses typically include crimes such as homicide, aggravated assault, robbery, and sexual assault. The unit of measurement is a simple count of arrests. For example, if there were 50,000 violent offense arrests in 2019 and 45,000 in 2020, that would represent a decrease of 5,000 arrests year over year. By aggregating violent offense counts annually, we can observe whether violent crime trends increased, decreased, or remained relatively stable over time. These yearly totals allow us to compare patterns before, during, and after the COVID-19 period.

# %%
# Loading dataframes for every year
texas_offenses_2019 = pd.read_csv('data/00-raw/texas_crime_reports/texas_offenses_2019.csv')
texas_offenses_2020 = pd.read_csv('data/00-raw/texas_crime_reports/texas_offenses_2020.csv')
texas_offenses_2021 = pd.read_csv('data/00-raw/texas_crime_reports/texas_offenses_2021.csv')
texas_offenses_2022 = pd.read_csv('data/00-raw/texas_crime_reports/texas_offenses_2022.csv')
texas_offenses_2023 = pd.read_csv('data/00-raw/texas_crime_reports/texas_offenses_2023.csv')
texas_offenses_2024 = pd.read_csv('data/00-raw/texas_crime_reports/texas_offenses_2024.csv')

# %%
# -----------------------------
# SETUP
# -----------------------------

list_of_dfs = [
    texas_offenses_2019,
    texas_offenses_2020,
    texas_offenses_2021,
    texas_offenses_2022,
    texas_offenses_2023,
    texas_offenses_2024
]

# Standard UCR offense codes
offense_codes_standard = {
    '11A': 'Rape',
    '09A': 'Murder and Nonnegligent Manslaughter',
    '120': 'Robbery',
    '13A': 'Aggravated Assault'
}

# Alternate coding system
offense_codes_alt = {
    '36': 'Rape',
    '32': 'Murder and Nonnegligent Manslaughter',
    '40': 'Robbery',
    '27': 'Aggravated Assault'
}

# DataFrames that use alternate codes
alt_code_indices = [0, 1]

processed_dfs = []

# -----------------------------
# PROCESS DATA
# -----------------------------

for i, df in enumerate(list_of_dfs):

    # Normalize column names
    df = df.copy()
    df.columns = df.columns.str.lower()

    # Standardize offense column name
    if 'offense_type_id' in df.columns:
        df = df.rename(columns={'offense_type_id': 'offense_code'})

    # Select only needed columns
    df = df.loc[:, ['data_year', 'offense_code']]

    # Normalize offense_code values
    df['offense_code'] = (
        df['offense_code']
        .astype(str)
        .str.strip()
        .str.upper()
    )

    # Apply correct mapping
    if i in alt_code_indices:
        df['offense_code'] = df['offense_code'].map(offense_codes_alt)
    else:
        df['offense_code'] = df['offense_code'].map(offense_codes_standard)

    # Drop rows not in our crimes of interest
    df = df.dropna(subset=['offense_code'])

    processed_dfs.append(df)

# -----------------------------
# COMBINE ALL DATA
# -----------------------------

texas_offenses_all = pd.concat(processed_dfs, ignore_index=True)

# -----------------------------
# SAVE TO 02-PROCESSED
# -----------------------------

output_dir = "data/02-processed"
os.makedirs(output_dir, exist_ok=True)

output_path = os.path.join(output_dir, "texas_offenses_clean.csv")
texas_offenses_all.to_csv(output_path, index=False)

# %%
# Reload the saved clean crime data
texas_offenses_all = pd.read_csv('data/02-processed/texas_offenses_clean.csv')

display(texas_offenses_all.head())

print("Shape:", texas_offenses_all.shape)
print("\nData Types:\n", texas_offenses_all.dtypes)
print("\nNull Counts:\n", texas_offenses_all.isnull().sum())
print("\nNull Proportions:\n", texas_offenses_all.isnull().mean().round(4))
print("\nOffenses by Year:\n", texas_offenses_all['data_year'].value_counts().sort_index())
print("\nOffense Type Breakdown:\n", texas_offenses_all['offense_code'].value_counts())
print("\nOffense Type by Year:")
print(pd.crosstab(texas_offenses_all['data_year'], texas_offenses_all['offense_code']))

print(f"\nNumber of unique rows in offense_id: {texas_offenses_all['offense_id'].nunique()} | This matches the number of rows in the dataset, therefore, each row is an offense.")
# Out:
#    data_year        offense_code  offense_id
# 0       2019  Aggravated Assault   138373905
# 1       2019  Aggravated Assault   138384764
# 2       2019  Aggravated Assault   138375422
# 3       2019             Robbery   138386805
# 4       2019  Aggravated Assault   138386979
# Shape: (583834, 3)
#
# Data Types:
#  data_year        int64
# offense_code    object
# offense_id       int64
# dtype: object
#
# Null Counts:
#  data_year       0
# offense_code    0
# offense_id      0
# dtype: int64
#
# Null Proportions:
#  data_year       0.0
# offense_code    0.0
# offense_id      0.0
# dtype: float64
#
# Offenses by Year:
#  data_year
# 2019     67504
# 2020     91819
# 2021    109716
# 2022    107830
# 2023    104051
# 2024    102914
# Name: count, dtype: int64
#
# Offense Type Breakdown:
#  offense_code
# Aggravated Assault                      388490
# Robbery                                 128825
# Rape                                     57230
# ...

# %% [markdown]
# ## Texas Crime Reports - Monthly
#
# This dataset is from the same source as the previous dataset. Our group has decided to add this dataset to get finer-grain detail on the rise and fall of crime rates on a monthly basis, rather than yearly. The variables of this dataset are the type of crime, the month the crime was committed in, and number of attempted, completed, and total crimes for the month. This data will be used to track crime rates per month, and can be broken down further to analyze the type of crime committed per month.

# %%
import pandas as pd
import os

# Load dataframe from 00-raw
monthly_crime_df = pd.read_csv('data/00-raw/texas_crime_reports_monthly/texas_offenses_monthly.csv')

# Forward-fill offense names
monthly_crime_df['Offense'] = monthly_crime_df['Offense'].ffill()

# Keep only required offense codes
target_codes = ['11A', '09A', '120', '13A']
monthly_crime_df = monthly_crime_df[
    monthly_crime_df['Offense'].str.contains('|'.join(target_codes), na=False)
].copy()

# Map to clean offense names
offense_labels = {
    '11A': 'Rape',
    '09A': 'Murder and Nonnegligent Manslaughter',
    '120': 'Robbery',
    '13A': 'Aggravated Assault'
}

monthly_crime_df['OffenseCode'] = monthly_crime_df['Offense'].str.extract(r'(11A|09A|120|13A)')
monthly_crime_df['Offense'] = monthly_crime_df['OffenseCode'].map(offense_labels)

# Clean month column
monthly_crime_df['Month'] = pd.to_datetime(
    monthly_crime_df['Month'],
    format='%b - %Y'
)

# Remove commas from numeric columns
cols = ['Attempted', 'Completed', 'Total']
for col in cols:
    monthly_crime_df[col] = (
        monthly_crime_df[col]
        .astype(str)
        .str.replace(',', '', regex=False)
    )

# Convert numeric columns
monthly_crime_df[cols] = monthly_crime_df[cols].apply(
    pd.to_numeric,
    errors='coerce'
)

# Convert to tidy format
tidy_crime_df = monthly_crime_df.melt(
    id_vars=['Month', 'Offense'],
    value_vars=['Attempted', 'Completed'],
    var_name='Outcome',
    value_name='Count'
).dropna(subset=['Count'])

# Sort
tidy_crime_df = tidy_crime_df.sort_values(['Offense', 'Month'])

# Save cleaned file
output_dir = "data/02-processed"
os.makedirs(output_dir, exist_ok=True)

output_path = os.path.join(output_dir, "texas_offenses_monthly_clean.csv")
tidy_crime_df.to_csv(output_path, index=False)

# %%
# Reload the saved clean crime data
texas_offenses_all_monthly = pd.read_csv('data/02-processed/texas_offenses_monthly_clean.csv')
print('\nEach row represents the monthly count for a particular offense type\n')
display(texas_offenses_all_monthly.head())

print("Shape:", texas_offenses_all_monthly.shape)
print("\nData Types:\n", texas_offenses_all_monthly.dtypes)
print("\nNull Counts:\n", texas_offenses_all_monthly.isnull().sum())
print("\nNull Proportions:\n", texas_offenses_all_monthly.isnull().mean().round(4))

# Convert Month column to datetime
texas_offenses_all_monthly['Month'] = pd.to_datetime(texas_offenses_all_monthly['Month'])

# Offenses by year (total)
offenses_by_year = texas_offenses_all_monthly.groupby(
    texas_offenses_all_monthly['Month'].dt.year
)['Count'].sum().astype(int)
offenses_by_year.index.name = 'Year'

print("\nOffenses by Year:\n", offenses_by_year)

# Offense type breakdown (total across all months)
offense_type_total = texas_offenses_all_monthly.groupby('Offense')['Count'].sum().astype(int)
print("\nOffense Type Breakdown:\n", offense_type_total)

# Offense type by year
offense_by_year = texas_offenses_all_monthly.groupby(
    [texas_offenses_all_monthly['Month'].dt.year, 'Offense']
)['Count'].sum().unstack(fill_value=0).astype(int)
offense_by_year.index.name = 'Year'

print("\nOffense Type by Year:")
print(offense_by_year)
# Out:
# Each row represents the monthly count for a particular offense type
#         Month             Offense    Outcome   Count
# 0  2019-01-01  Aggravated Assault  Completed  3347.0
# 1  2019-02-01  Aggravated Assault  Completed  2997.0
# 2  2019-03-01  Aggravated Assault  Completed  3838.0
# 3  2019-04-01  Aggravated Assault  Completed  3706.0
# 4  2019-05-01  Aggravated Assault  Completed  4375.0
# Shape: (432, 4)
#
# Data Types:
#  Month       object
# Offense     object
# Outcome     object
# Count      float64
# dtype: object
#
# Null Counts:
#  Month      0
# Offense    0
# Outcome    0
# Count      0
# dtype: int64
#
# Null Proportions:
#  Month      0.0
# Offense    0.0
# Outcome    0.0
# Count      0.0
# dtype: float64
#
# Offenses by Year:
#  Year
# 2019     78805
# 2020    107974
# 2021    129587
# 2022    127903
# 2023    122292
# 2024    119882
# Name: Count, dtype: int64
#
# Offense Type Breakdown:
#  Offense
# Aggravated Assault                      481277
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# After the data wrangling, we now have datasets `ice_arrests_clean`, `texas_offenses_clean`, and `texas_offenses_monthly_clean`. With this data, we can look at the relationships between ICE arrests and crime trends over time, which will have statistical information that will be used in verifying our hypothesis.
#
# This EDA is split into three sections:
# * Section 1 will observe ICE arrests over years, criminal arrests over years, and the relationship between these who metrics.
# * Section 2 will observe these same metrics, but on a monthly basis instead
# * Section 3 will display the distribution of the most serious crime of an ICE detainee, as well as the monthly ICE arrests per area of responsibility

# %% [markdown]
# #### Section 1 of EDA - ICE Arrest and Crime Trends Over Time
#
# First we will look into the temporal trends of each dataset individually to get an idea of the distribution of each dataset before they are analyzed together.

# %%
# plot distribution of ICE arrests over time
import pandas as pd
import matplotlib.pyplot as plt

# load data
ice_df = pd.read_csv('data/02-processed/ice_arrests_clean.csv')

# find counts of arrests per month
ice_df['datetime'] = pd.to_datetime(ice_df['Apprehension Date And Time'])
monthly = ice_df.set_index('datetime').resample('M').size()

# plot figure
plt.figure()
plt.plot(monthly.index, monthly.values)
plt.xlabel('Date')
plt.ylabel('Number of ICE Arrests')
plt.title('Monthly ICE Arrests Over Time')
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1386/3433573166.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = ice_df.set_index('datetime').resample('M').size()

# %% [markdown]
# An initial look at the data shows that the number of ICE arrests greatly vary month to month from 2019-2025. This volatility is due to a number of funding cycles and policy shifts. For example, ICE arrests are limited when detention centers are full. When the budget increases ([One Big Beautiful Bill Act](https://www.npr.org/2026/01/21/nx-s1-5674887/ice-budget-funding-congress-trump)) the capacity to detain more people increases, leading to a spike in the graph.

# %%
def plot_time_series(crime, crime_type):
    # function for plotting distribution of crime over time

    # find counts of crime per year
    yearly_counts = crime.groupby('data_year').size()

    # plot figure
    plt.figure()
    plt.plot(yearly_counts.index, yearly_counts.values)
    plt.xlabel('Year')
    if crime_type == 'Crime (all)':
        plt.ylabel('Number of Crimes (all)')
        plt.title(f'{crime_type} Per Year')
    elif crime_type == 'Robbery':
        plt.ylabel('Number of Robberies')
        plt.title('Robberies Per Year')
    else:
        plt.ylabel(f'Number of {crime_type}s')
        plt.title(f'{crime_type}s Per Year')
    plt.show()

# %%
# load data
crime_df = pd.read_csv('data/02-processed/texas_offenses_clean.csv')

# plot time series of crime overall
plot_time_series(crime_df, 'Crime (all)')

# plot time series for each type of crime
crime_categories = ['Rape', 'Murder and Nonnegligent Manslaughter', 'Robbery', 'Aggravated Assault']

for crime_type in crime_categories:
    crime_df_new = crime_df[crime_df['offense_code'] == crime_type]
    plot_time_series(crime_df_new, crime_type)

# %% [markdown]
# It is evident that the number of crimes increased between the years 2019 and 2021. This aligns with the COVID-19 pandemic, which caused social disruption and economic stress in Texas. One potential factor to consider is the increase of firearm presence in Texas. According to ammo.com, over 5 million firearms were purchased between 2020 and 2023. Is the decrease of the amount of crime caused by an increase of ICE arrests?

# %% [markdown]
# #### Section 2 of EDA - Correlation Between ICE Arrests and Crime per Year
#
# The plots here show the relationship between the number of ICE arrests and the amount of crime in Texas for each year.

# %%
def plot_correlation(crime, crime_type):
    # function for plotting correlation between ICE arrests and crime

    # find counts of ICE arrests and crime by year
    ice_df['datetime'] = pd.to_datetime(ice_df['Apprehension Date And Time'])
    ice_yearly = ice_df.set_index('datetime').resample('Y').size()
    ice_yearly.index = ice_yearly.index.year
    crime_yearly = crime.groupby('data_year').size()

    # combine ICE arrests and crime into one dataframe
    combined = pd.DataFrame({
        'ice_arrests': ice_yearly,
        'crime_count': crime_yearly
    })

    # plotting
    sns.regplot(x='ice_arrests', y='crime_count', data=combined)

    for year, row in combined.iterrows():
        plt.text(
            x=row['ice_arrests'], 
            y=row['crime_count'], 
            s=str(int(year)), # The year is the index
            fontsize=9,
            verticalalignment='bottom', 
            horizontalalignment='right'
        )

    plt.title(f'Correlation Between ICE Arrests and {crime_type}')
    plt.xlabel('ICE Arrests')
    plt.ylabel(f'{crime_type} Count')
    plt.show()

    

    # print out correlation coefficient
    corr_value = combined['ice_arrests'].corr(combined['crime_count'])
    print(f'Correlation coefficient is {corr_value:.3f}')

# %%
import seaborn as sns

# plot correlation between ICE arrests and crime overall
plot_correlation(crime_df, 'All Crime')

# plot correlation between ICE arrests and each type of crime
crime_categories = ['Rape', 'Murder and Nonnegligent Manslaughter', 'Robbery', 'Aggravated Assault']

for crime_type in crime_categories:
    crime_df_new = crime_df[crime_df['offense_code'] == crime_type]
    plot_correlation(crime_df_new, crime_type)
# Out:
# /tmp/ipykernel_1386/3090394567.py:6: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   ice_yearly = ice_df.set_index('datetime').resample('Y').size()
# Correlation coefficient is -0.404
# /tmp/ipykernel_1386/3090394567.py:6: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   ice_yearly = ice_df.set_index('datetime').resample('Y').size()
# Correlation coefficient is -0.298
# /tmp/ipykernel_1386/3090394567.py:6: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   ice_yearly = ice_df.set_index('datetime').resample('Y').size()
# Correlation coefficient is -0.387
# /tmp/ipykernel_1386/3090394567.py:6: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   ice_yearly = ice_df.set_index('datetime').resample('Y').size()
# Correlation coefficient is -0.352
# ...

# %% [markdown]
# #### Section 3 of EDA - Analysis of ICE Arrests and Crime at a Monthly Level
#
# To investigate further from the previous section, here we will be analyzing the data at the monthly level, which will give a more detailed view of the relationship between ICE arrests and crime. The plots in this section include the monthly time series of each type of crime, and also the correlation between ICE arrests and crime using the counts per month.

# %%
def plot_time_series_monthly(monthly_crime_df, crime_type):
    # function for plotting distribution of crime over time for the monthly data

    # convert to datetime
    monthly_crime_df['Month'] = pd.to_datetime(monthly_crime_df['Month'])

    # combine all crime categories per month
    monthly_totals = monthly_crime_df.groupby('Month')['Count'].sum().reset_index()

    # plot
    plt.figure()
    plt.plot(monthly_totals['Month'], monthly_totals['Count'])
    plt.xlabel('Date')
    if crime_type == 'Crime (all)':
        plt.ylabel('Number of Crimes (all)')
        plt.title(f'{crime_type} Per Month')
    elif crime_type == 'Robbery':
        plt.ylabel('Number of Robberies')
        plt.title('Robberies Per Month')
    else:
        plt.ylabel(f'Number of {crime_type}s')
        plt.title(f'{crime_type}s Per Month')
    plt.xticks(rotation=45)
    plt.show()

# %%
# load data
monthly_crime_df = pd.read_csv('data/02-processed/texas_offenses_monthly_clean.csv')

# plot time series of crime overall
plot_time_series_monthly(monthly_crime_df, 'Crime (all)')

# plot time series for each type of crime
crime_categories = ['Rape', 'Murder and Nonnegligent Manslaughter', 'Robbery', 'Aggravated Assault']

for crime_type in crime_categories:
    crime_df_new = monthly_crime_df[crime_df['offense_code'] == crime_type]
    plot_time_series_monthly(crime_df_new, crime_type)
# Out:
# /tmp/ipykernel_1386/2840373659.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crime_df_new = monthly_crime_df[crime_df['offense_code'] == crime_type]
# /tmp/ipykernel_1386/2570228974.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monthly_crime_df['Month'] = pd.to_datetime(monthly_crime_df['Month'])
# /tmp/ipykernel_1386/2840373659.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crime_df_new = monthly_crime_df[crime_df['offense_code'] == crime_type]
# /tmp/ipykernel_1386/2570228974.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
def plot_correlation_monthly(ice_df, monthly_crime_df, crime_type):
    # function for plotting correlation between ICE arrests and crime

    # find counts of ICE arrests and crime by year
    ice_df['datetime'] = pd.to_datetime(ice_df['Apprehension Date And Time'])
    ice_monthly = ice_df.set_index('datetime').resample('M').size()
    ice_monthly.index = ice_monthly.index.year


    # convert to datetime
    monthly_crime_df['Month'] = pd.to_datetime(monthly_crime_df['Month'])

    # combine all crime categories per month
    crime_monthly = monthly_crime_df.groupby('Month')['Count'].sum().reset_index()


    ice_counts = ice_monthly.reset_index(drop=True)
    crime_monthly = crime_monthly.sort_values('Month').reset_index(drop=True)
    crime_monthly['ice_arrests'] = ice_counts
    
    # plotting
    sns.regplot(x='ice_arrests', y='Count', data=crime_monthly)

    plt.title(f'Correlation Between ICE Arrests and {crime_type}')
    plt.xlabel('ICE Arrests')
    plt.ylabel(f'{crime_type} Count')
    plt.show()

    # print out correlation coefficient
    corr_value = crime_monthly['ice_arrests'].corr(crime_monthly['Count'])
    print(f'Correlation coefficient is {corr_value:.3f}')

# %%
# load data
monthly_crime_df = pd.read_csv('data/02-processed/texas_offenses_monthly_clean.csv')
ice_df = pd.read_csv('data/02-processed/ice_arrests_clean.csv')

# plot correlation between ICE arrests and crime overall
plot_correlation_monthly(ice_df, monthly_crime_df, 'All Crime')

# plot correlation between ICE arrests and each type of crime
crime_categories = ['Rape', 'Murder and Nonnegligent Manslaughter', 'Robbery', 'Aggravated Assault']

for crime_type in crime_categories:
    crime_df_new = monthly_crime_df[crime_df['offense_code'] == crime_type]
    plot_correlation_monthly(ice_df, crime_df_new, crime_type)
# Out:
# /tmp/ipykernel_1386/4139853462.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ice_monthly = ice_df.set_index('datetime').resample('M').size()
# Correlation coefficient is -0.271
# /tmp/ipykernel_1386/512251901.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crime_df_new = monthly_crime_df[crime_df['offense_code'] == crime_type]
# /tmp/ipykernel_1386/4139853462.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   ice_monthly = ice_df.set_index('datetime').resample('M').size()
# /tmp/ipykernel_1386/4139853462.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# #### Section 4 of EDA - Analysis of Other Variables from the ICE dataset
#
# Lastly, we are looking at the distribution of crimes committed that led to ICE detainments, as well as the number of ICE arrests in areas of responsibilities over time. This can help add extra context to our understanding of whether enforcement priorities are focusing on public safety threats or, conversely, targetting a wider group which includes individuals with minor or no criminal records.

# %%
# load data
ice_df = pd.read_csv('data/02-processed/ice_arrests_clean.csv')

final_clean_ice['Most Serious Crime Class'].value_counts().plot(kind='bar')
plt.xlabel('Crime Class')
plt.ylabel('Count')
plt.title('Distribution of Most Serious Crime Class of Each Person Arrested by ICE')
plt.show()

# %%
# Convert to datetime
ice_df['datetime'] = pd.to_datetime(ice_df['Apprehension Date And Time'])

# Group by month and AOR, count arrests
monthly_aor = ice_df.groupby([pd.Grouper(key='datetime', freq='M'), 'Apprehension AOR']).size().unstack(fill_value=0)

# Plot
plt.figure(figsize=(12,6))

for aor in monthly_aor.columns:
    plt.plot(monthly_aor.index, monthly_aor[aor], label=aor)

plt.xlabel('Date')
plt.ylabel('Number of ICE Arrests')
plt.title('Monthly ICE Arrests by Area of Responsibility')
plt.xticks(rotation=45)
plt.legend(title='AOR')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1386/700984831.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_aor = ice_df.groupby([pd.Grouper(key='datetime', freq='M'), 'Apprehension AOR']).size().unstack(fill_value=0)

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# There could be some sources of bias in our data, for example since the ICE arrest records come from ICE themselves, we do not know if they choose to leave certain arrests unrecorded. The same type of bias also applies to the data of crime rate, since some crimes may go unrecorded. Also, there could be bias in the way that the data was recorded across different areas, for instance some places could be more strict in what they record than others.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# The data we are using does not use personally identifiable information.  The data sources has encrypted any identifying documents. We still have data about demographics and location, but people’s personal information is safe.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# The methods used in this project should be able to be applied on data collected in the future so long as the formatting of data is similar.
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# Since our data was obtained from reputable open sources, the danger of exposing personal information was extremely minimal. While encryption at rest and in transit is not applicable, our data will be stored on the private team project repository only accessible by invited members on Github. Any changes to our data will be recorded by version control, to minimize accidental deletion or modifications.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# Data will only be accessed during the progression of the project and later deleted from our local systems upon completion. The data will exist in the Github repository with no plan to delete it for future academic purposes.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# We plan on making sure that we do not reinforce harmful stereotypes by discussing amongst each other as well as reaching out to those in affected communities
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# We are aware of the possibilities of misreporting statistics and other variables and will try to account for this error
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# We will only present what the data shows and not draw any unnecessary conclusions.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# This data doesn't use personally identifiable information. In case we come across this, we will not display any unnecessary data that may break privacy.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# We will document our process of analysis with explanations of our findings. The documentation of our analysis will include every step we took to analyze the data so that it will be reproducible in the future.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# We recognize that the two main variables of our study, ICE arrests and criminal offenses per capita, are closely intertwined with historically discriminatory socio-economic factors. While the data may reflect systemic discriminatory bias, we do not believe the data itself is unfairly discriminatory. Our project works to analyze the hypothesized cross-over between two groups of people, those arrested by ICE and those who have committed a criminal offense.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# As previously mentioned, we recognize that data regarding criminal offenses and ICE arrests exist within a socio-economic and political context. The criminal justice system disproportionately affects marginalized communities, which will be reflected in released datasets. As a group, we will analyze our findings with this in mind, knowing that the representation of people groups within the two categories of criminal offenses and ICE arrests are not reflective of a just system.
#
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# In regards to decisions made by the model, we will describe findings through a combination of diagrams and clearly outlined explanations. Explanations will include relevant variables and necessary context to ensure understanding.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#  It's stated that this model only measures the relationship between Texas crime per capita and ICE arrests per capita, so the model is only limited to this scope and has been communicated as such.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# There is a plan to monitor the downstream impacts as well as to regularly check to verify the accuracy of the model.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# It's been discussed on how to evaluate the potential harm that this model can do and measures have been taken in order to update the model if need be.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# Because the data from the Texas crime reports and ICE arrests are divided by year, we can remove newer data if needed and re-run the data wrangling in order to rollback the model. Furthermore, there are systems in place to turn off the model if necessary.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# There is no way to fully cover this models misuse. However, there have been steps taken in the Research Question, Background Work, and Hypothesis to try and prevent it. Furthermore, there are plans to monitor the effects of this model after it has been deployed.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Each group member should check in regularly and respond within a reasonable timeframe to ensure tasks are coordinated and questions are addressed quickly.*
# * *Every team member contributes meaningfully to all project phases and is accountable for completing assigned tasks on time. 2*
# * *All work should be committed to the team’s GitHub repository with clear commit messages, frequent commits, and proper branching (e.g., each feature on its own branch) to ensure version control and transparency among teammates. 3*
# * *Team members should treat each other with respect, be open to constructive feedback, and resolve differences through discussion and compromise to maintain a productive team environment.*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  1 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/26  |  10 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/3  |  5 PM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/14  | 6 PM  | Import & Wrangle Data (Juan); EDA (Dylan) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 2/23  | 12 PM  | Finalize wrangling/EDA; Begin Analysis (Russell; Sierra) | Discuss/edit Analysis; Complete project check-in |
# | 3/13  | 12 PM  | Complete analysis; Draft results/conclusion/discussion (Ellen)| Discuss/edit full project |
# | 3/20  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
