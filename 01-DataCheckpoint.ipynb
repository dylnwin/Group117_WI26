# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
# |                  | Unsatisfactory                                                                                                                                                                                                    | Developing                                                                                                                                                                                              | Proficient                                     | Excellent                                                                                                                              |
# |------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|
# | Data relevance   | Did not have data relevant to their question. Or the datasets don't work together because there is no way to line them up against each other. If there are multiple datasets, most of them have this trouble | Data was only tangentially relevant to the question or a bad proxy for the question. If there are multiple datasets, some of them may be irrelevant or can't be easily combined.                       | All data sources are relevant to the question. | Multiple data sources for each aspect of the project. It's clear how the data supports the needs of the project.                         |
# | Data description | Dataset or its cleaning procedures are not described. If there are multiple datasets, most have this trouble                                                                                              | Data was not fully described. If there are multiple datasets, some of them are not fully described                                                                                                      | Data was fully described                       | The details of the data descriptions and perhaps some very basic EDA also make it clear how the data supports the needs of the project. |
# | Data wrangling   | Did not obtain data. They did not clean/tidy the data they obtained.  If there are multiple datasets, most have this trouble                                                                                 | Data was partially cleaned or tidied. Perhaps you struggled to verify that the data was clean because they did not present it well. If there are multiple datasets, some have this trouble | The data is cleaned and tidied.                | The data is spotless and they used tools to visualize the data cleanliness and you were convinced at first glance                      |

# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
#
# Sierra Peng: Conceptualization, Data curation, Methodology, Writing - original draft
#
# Dylan Nguyen: Project administration, Software, Visualization, Writing - original draft
#
# Juan Bello:   Analysis, Software, Writing - review & editing
#
# Ellen Kwon: Analysis, Background research, Visualization, Writing - original draft
#
# Russel Wong: Conceptualization, Data curation, Analysis, Methodology

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there a statistically significant association between the ICE arrests per capita and reported violent and property crime rates at the county level in the state of Texas between 2011 and 2025?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Immigration and Customs Enforcement (ICE) is a federal agency acting under the Department of Homeland Security. The main responsibilities of ICE include enforcing immigration law, preventing terrorism, and stopping illegal movement of people and goods within the United States.
#
# The motivation for exploring our topic lies in the dramatic increase in funding that ICE has received with the One Big Beautiful Bill Act. Prior to the passage of the One Big Beautiful Bill Act, ICE received about 10 dollars billion in budget per year. After passing, funding increased to 85 billion dollars. With the marked uptick in funding, activity, and media coverage, ICE has become a hotly contested topic for the American public in recent months, especially with notable incidents involving Renee Good and Alex Pretti. We will attempt to gain a better understanding of the efficacy of ICE on reducing violent and property crime.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1)
#
# An article published in the The Journal of Law & Economics by Thomas J. Miles and Adam B. Cox examined the relationship between immigration enforcement and local US crime rates. The research specifically investigates the effect of the Secure Communities program. The Secure Communities program uses fingerprint-sharing between local law enforcement and federal immigration authorities to facilitate detention and removal of noncitizens. This is not a direct correlate to ICE, however, it may serve as a proxy to understand whether or not strict enforcement of immigration policy reduces crime. The conclusion of the study showed that the Secure Communities program led to hundreds of thousands of detentions, but did not reduce crime-rates as expected.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# The article Immigration and Customs Enforcement Raids the Pillar of a Community: Student Achievement, Absenteeism, and Mobility Following a Large Worksite Enforcement Operation in North Texas looks at the effects that ICE had through various time extents. It serves as a point of interest as to why Texas was chosen for this project, as well as a way to question what sort of empirical and statistical impact ICE had.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3)
#
# Of all states affected by ICE, Texas stands out in the number and scale of people detained. According to data from the Transactional Records Access Clearinghouse (TRAC) Immigration, there are 18,684 people in detention, as of January 22, 2026, which makes Texas the state with the most ICE detainees followed by Louisiana, 8,207 people, and California, 6,422. Geographically, Texas shares the longest border between the U.S. and Mexico, stretching 382 miles, with more than 40 border security stations across 5 sectors. The sheer size of the border and affiliated border control stations are key in understanding the subsequent size of detainees in Texas, which should be considered when examining the correlation between violent crime and ICE arrests. While Texas holds the greatest number of detainees, it is critical to understand that detention location is not the same as arrest location. Texas maintains some of the largest ICE detention centers in the country, where those arrested by ICE both in and out of Texas may be placed into. Therefore it is more representative to examine arrests per capita, to measure the presence of ICE in Texas independent from other states.<a name="cite_ref-4"></a>[<sup>4,</sup>](#cite_note-4)<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Chappell, Bill. “How ICE Grew to Be the Highest-Funded U.S. Law Enforcement Agency.” NPR, 21 Jan. 2026, www.npr.org/2026/01/21/nx-s1-5674887/ice-budget-funding-congress-trump.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Miles, T. J., & Cox, A. B. (2014). Does Immigration Enforcement Reduce Crime? Evidence from Secure Communities. The Journal of Law and Economics, 57(4), 937–973. https://doi.org/10.1086/680935
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) J. Jacob Kirksey, and Carolyn Sattin-Bajaj. “Immigration and Customs Enforcement Raids the Pillar of a Community: Student Achievement, Absenteeism, and Mobility Following a Large Worksite Enforcement Operation in North Texas.” American Behavioral Scientist, 28 Nov. 2023, https://doi.org/10.1177/00027642231215992.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)U.S. Customs and Border Protection. (2025, n.d.). Border Patrol sectors. U.S. Department of Homeland Security. https://www.cbp.gov/border-security/along-us-borders/border-patrol-sectors
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)Transactional Records Access Clearinghouse. (2026). Immigration Quick Facts. https://tracreports.org/immigration/quickfacts/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# There will be no statistically significant relationship between the level of ICE arrests and overall violent and property crime rates in Texas once adjusted for population size and socioeconomic factors, including poverty rate, unemployment rate, and median income. This hypothesis is based on the study on the Secure Communities program which did not reduce crime rates despite detaining hundreds of thousands of immigrants.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with descriptions of your actual datasets.
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
#   - Description of the variables most relevant to this project
#   - Descriptions of any shortcomings this dataset has with repsect to the project
# - Dataset #2 (if you have more than one!)
#   - same as above
# - etc
#
# Each dataset deserves either a set of bullet points as above or a few sentences if you prefer that method.
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_2112094399060', 'filename':'ice_oct2018-sep2019.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851835191968', 'filename':'ice_oct2019-sep2020.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_2112096507807', 'filename':'ice_oct2020-sep2021.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851830686826', 'filename':'ice_oct2021-sep2022.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851836416108', 'filename':'ice_oct2022-sep2023.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_1851836311169', 'filename':'ice_oct2023-sep2024.xlsx'},
    { 'url': 'https://ucla.app.box.com/index.php?rm=box_download_shared_file&shared_name=9d8qnnduhus4bd5mwqt7l95kz34fic2v&file_id=f_2112094399060', 'filename':'ice_oct2024-apr2025.xlsx'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/ice_arrests')
# Out:
# Overall Download Progress:   0%|          | 0/7 [00:00<?, ?it/s]
# Downloading ice_oct2018-sep2019.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2018-sep2019.xlsx: 1.67MB [00:00, 16.7MB/s]
# Downloading ice_oct2018-sep2019.xlsx: 7.38MB [00:00, 40.5MB/s]
# Downloading ice_oct2018-sep2019.xlsx: 19.0MB [00:00, 75.1MB/s]
# Downloading ice_oct2018-sep2019.xlsx: 29.4MB [00:00, 86.0MB/s]
# Downloading ice_oct2018-sep2019.xlsx: 41.0MB [00:00, 97.0MB/s]
# Downloading ice_oct2018-sep2019.xlsx: 51.7MB [00:00, 100MB/s]
# Downloading ice_oct2018-sep2019.xlsx: 63.4MB [00:00, 106MB/s]
# Overall Download Progress:  14%|█▍        | 1/7 [00:02<00:12,  2.04s/it]
# Successfully downloaded: ice_oct2018-sep2019.xlsx
# Downloading ice_oct2019-sep2020.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2019-sep2020.xlsx: 6.73MB [00:00, 67.3MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 13.5MB [00:00, 28.3MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 17.4MB [00:00, 22.4MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 20.6MB [00:00, 19.6MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 24.8MB [00:01, 19.5MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 29.0MB [00:01, 19.9MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 33.1MB [00:01, 21.2MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 37.2MB [00:01, 21.2MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 41.5MB [00:01, 21.1MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 45.7MB [00:02, 20.8MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 49.9MB [00:02, 20.5MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 54.0MB [00:02, 19.7MB/s]
# Downloading ice_oct2019-sep2020.xlsx: 58.7MB [00:02, 22.7MB/s]
# Overall Download Progress:  29%|██▊       | 2/7 [00:06<00:16,  3.23s/it]
# Successfully downloaded: ice_oct2019-sep2020.xlsx
# Downloading ice_oct2020-sep2021.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2020-sep2021.xlsx: 10.2MB [00:00, 102MB/s]
# Downloading ice_oct2020-sep2021.xlsx: 21.2MB [00:00, 107MB/s]
# Downloading ice_oct2020-sep2021.xlsx: 32.4MB [00:00, 109MB/s]
# Downloading ice_oct2020-sep2021.xlsx: 43.2MB [00:00, 100MB/s]
# Overall Download Progress:  43%|████▎     | 3/7 [00:07<00:10,  2.52s/it]
# Successfully downloaded: ice_oct2020-sep2021.xlsx
# Downloading ice_oct2021-sep2022.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2021-sep2022.xlsx: 1.95MB [00:00, 19.3MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 3.93MB [00:00, 17.3MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 7.86MB [00:00, 15.3MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 12.6MB [00:00, 19.8MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 16.4MB [00:00, 19.1MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 21.0MB [00:01, 18.1MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 25.0MB [00:01, 18.4MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 29.1MB [00:01, 18.0MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 33.2MB [00:01, 17.3MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 37.7MB [00:02, 17.1MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 41.4MB [00:02, 15.5MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 45.9MB [00:02, 16.2MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 50.1MB [00:02, 16.0MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 54.1MB [00:03, 16.7MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 58.2MB [00:03, 13.3MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 62.5MB [00:03, 14.0MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 66.7MB [00:04, 15.8MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 70.9MB [00:04, 16.9MB/s]
# Downloading ice_oct2021-sep2022.xlsx: 75.5MB [00:04, 21.0MB/s]
# Overall Download Progress:  57%|█████▋    | 4/7 [00:13<00:11,  3.91s/it]
# Successfully downloaded: ice_oct2021-sep2022.xlsx
# Downloading ice_oct2022-sep2023.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2022-sep2023.xlsx: 2.36MB [00:00, 22.7MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 8.39MB [00:00, 37.7MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 12.3MB [00:00, 27.9MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 16.4MB [00:00, 30.5MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 20.7MB [00:00, 31.5MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 25.2MB [00:00, 29.5MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 29.4MB [00:00, 29.6MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 33.6MB [00:01, 26.8MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 37.1MB [00:01, 22.6MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 41.8MB [00:01, 23.2MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 46.1MB [00:01, 22.2MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 50.3MB [00:01, 21.7MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 53.7MB [00:02, 21.1MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 58.6MB [00:02, 22.1MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 62.5MB [00:02, 22.1MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 66.7MB [00:02, 25.7MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 71.3MB [00:02, 26.0MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 75.1MB [00:03, 24.5MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 79.3MB [00:03, 24.4MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 83.4MB [00:03, 24.3MB/s]
# Downloading ice_oct2022-sep2023.xlsx: 87.5MB [00:03, 27.0MB/s]
# Overall Download Progress:  71%|███████▏  | 5/7 [00:18<00:08,  4.32s/it]
# Successfully downloaded: ice_oct2022-sep2023.xlsx
# Downloading ice_oct2023-sep2024.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2023-sep2024.xlsx: 2.10MB [00:00, 20.5MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 8.13MB [00:00, 31.2MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 12.1MB [00:00, 27.7MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 16.5MB [00:00, 30.7MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 20.8MB [00:00, 26.2MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 25.1MB [00:01, 19.6MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 29.0MB [00:01, 19.7MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 33.0MB [00:01, 21.4MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 37.7MB [00:01, 22.3MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 41.5MB [00:01, 22.1MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 45.7MB [00:01, 22.6MB/s]
# Downloading ice_oct2023-sep2024.xlsx: 49.9MB [00:02, 25.2MB/s]
# Overall Download Progress:  86%|████████▌ | 6/7 [00:22<00:04,  4.12s/it]
# Successfully downloaded: ice_oct2023-sep2024.xlsx
# Downloading ice_oct2024-apr2025.xlsx: 0.00B [00:00, ?B/s]
# Downloading ice_oct2024-apr2025.xlsx: 1.87MB [00:00, 18.7MB/s]
# Downloading ice_oct2024-apr2025.xlsx: 8.13MB [00:00, 44.5MB/s]
# Downloading ice_oct2024-apr2025.xlsx: 20.4MB [00:00, 80.1MB/s]
# Downloading ice_oct2024-apr2025.xlsx: 32.3MB [00:00, 95.7MB/s]
# Downloading ice_oct2024-apr2025.xlsx: 42.1MB [00:00, 96.5MB/s]
# Downloading ice_oct2024-apr2025.xlsx: 55.5MB [00:00, 109MB/s]
# Downloading ice_oct2024-apr2025.xlsx: 67.2MB [00:00, 112MB/s]
# Overall Download Progress: 100%|██████████| 7/7 [00:24<00:00,  3.53s/it]
# Successfully downloaded: ice_oct2024-apr2025.xlsx

# %%
datafiles_crime = [
    { 'url': 'https://drive.google.com/file/d/1vUrRUCDvJfnjMEV2k3jT-jD9QH6Ax1pz/view?usp=share_link', 'filename':'texas_offenses_2019.csv'},
    { 'url': 'https://drive.google.com/file/d/1-iGlPAfnkI9qUClc9H-a1ySWY-RYssAn/view?usp=share_link', 'filename':'texas_offenses_2020.csv'},
    { 'url': 'https://drive.google.com/file/d/1SPwSRvfHo7P_n1-VTypUk2qns6lJNUMB/view?usp=share_link', 'filename':'texas_offenses_2021.csv'},
    { 'url': 'https://drive.google.com/file/d/1YA20c8y5EfLCh3DdIoPPUpoNHUm6f9G8/view?usp=share_link', 'filename':'texas_offenses_2022.csv'},
    { 'url': 'https://drive.google.com/file/d/1q6mbYv2bzWPiUcX-12HkaA7m6D-FDkbT/view?usp=share_link', 'filename':'texas_offenses_2023.csv'},
    { 'url': 'https://drive.google.com/file/d/1nirFhfidk26ksytkGnWUBwSMWehyKK9P/view?usp=share_link', 'filename':'texas_offenses_2024.csv'},
]

get_data.get_raw(datafiles_crime,destination_directory='data/00-raw/texas_crime_reports')
# Out:
# Overall Download Progress:   0%|          | 0/6 [00:00<?, ?it/s]
# Downloading texas_offenses_2019.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress:  17%|█▋        | 1/6 [00:00<00:01,  2.70it/s]
# Successfully downloaded: texas_offenses_2019.csv
# Downloading texas_offenses_2020.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress:  33%|███▎      | 2/6 [00:00<00:01,  2.63it/s]
# Successfully downloaded: texas_offenses_2020.csv
# Downloading texas_offenses_2021.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress:  50%|█████     | 3/6 [00:01<00:01,  2.88it/s]
# Successfully downloaded: texas_offenses_2021.csv
# Downloading texas_offenses_2022.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress:  67%|██████▋   | 4/6 [00:01<00:00,  3.05it/s]
# Successfully downloaded: texas_offenses_2022.csv
# Downloading texas_offenses_2023.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress:  83%|████████▎ | 5/6 [00:01<00:00,  2.95it/s]
# Successfully downloaded: texas_offenses_2023.csv
# Downloading texas_offenses_2024.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress: 100%|██████████| 6/6 [00:02<00:00,  2.97it/s]
# Successfully downloaded: texas_offenses_2024.csv

# %% [markdown]
# ### Dataset #1
#
# Instructions:
# 1. Change the header from Dataset #1 to something more descriptive of the dataset
# 2. Write a few paragraphs about this dataset. Make sure to cover
#    1. Describe the important metrics, what units they are in, and giv some sense of what they mean.  For example "Fasting blood glucose in units of mg glucose per deciliter of blood.  Normal values for healthy individuals range from 70 to 100 mg/dL.  Values 100-125 are prediabetic and values >125mg/dL indicate diabetes. Values <70 indicate hypoglycemia. Fasting idicates the patient hasn't eaten in the last 8 hours.  If blood glucose is >250 or <50 at any time (regardless of the time of last meal) the patient's life may be in immediate danger"
#    2. If there are any major concerns with the dataset, describe them. For example "Dataset is composed of people who are serious enough about eating healthy that they voluntarily downloaded an app dedicated to tracking their eating patterns. This sample is likely biased because of that self-selection. These people own smartphones and may be healthier and may have more disposable income than the average person.  Those who voluntarily log conscientiously and for long amounts of time are also likely even more interested in health than those who download the app and only log a bit before getting tired of it"
# 3. Use the cell below to
#     1. load the dataset
#     2. make the dataset tidy or demonstrate that it was already tidy
#     3. demonstrate the size of the dataset
#     4. find out how much data is missing, where its missing, and if its missing at random or seems to have any systematic relationships in its missingness
#     5. find and flag any outliers or suspicious entries
#     6. clean the data or demonstrate that it was already clean.  You may choose how to deal with missingness (dropna of fillna... how='any' or 'all') and you should justify your choice in some way
#     7. You will load raw data from `data/00-raw/`, you will (optionally) write intermediate stages of your work to `data/01-interim` and you will write the final fully wrangled version of your data to `data/02-processed`
# 4. Optionally you can also show some summary statistics for variables that you think are important to the project
# 5. Feel free to add more cells here if that's helpful for you

# %%
import pandas as pd
ice_df = pd.read_excel('data/00-raw/ice_arrests/ice_oct2018-sep2019.xlsx')
ice_df.head()

# %% [markdown]
# ### Dataset #2
#
# See instructions above for Dataset #1.  Feel free to keep adding as many more datasets as you need.  Put each new dataset in its own section just like these.
#
# Lastly if you do have multiple datasets, add another section where you demonstrate how you will join, align, cross-reference or whatever to combine data from the different datasets
#
# Please note that you can always keep adding more datasets in the future if these datasets you turn in for the checkpoint aren't sufficient.  The goal here is demonstrate that you can obtain and wrangle data.  You are not tied down to only use what you turn in right now.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE

# %% [markdown]
# ## Ethics

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# There could be some sources of bias in our data, for example since the ICE arrest records come from ICE themselves, we do not know if they choose to leave certain arrests unrecorded. The same type of bias also applies to the data of crime rate, since some crimes may go unrecorded. Also, there could be bias in the way that the data was recorded across different areas, for instance some places could be more strict in what they record than others.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# The data we are using does not use personally identifiable information.  The data sources has encrypted any identifying documents. We still have data about demographics and location, but people’s personal information is safe.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# The methods used in this project should be able to be applied on data collected in the future so long as the formatting of data is similar.
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# Since our data was obtained from reputable open sources, the danger of exposing personal information was extremely minimal. While encryption at rest and in transit is not applicable, our data will be stored on the private team project repository only accessible by invited members on Github. Any changes to our data will be recorded by version control, to minimize accidental deletion or modifications.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# Data will only be accessed during the progression of the project and later deleted from our local systems upon completion. The data will exist in the Github repository with no plan to delete it for future academic purposes.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# We plan on making sure that we do not reinforce harmful stereotypes by discussing amongst each other as well as reaching out to those in affected communities
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# We are aware of the possibilities of misreporting statistics and other variables and will try to account for this error
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# We will only present what the data shows and not draw any unnecessary conclusions.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# This data doesn't use personally identifiable information. In case we come across this, we will not display any unnecessary data that may break privacy.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# We will document our process of analysis with explanations of our findings. The documentation of our analysis will include every step we took to analyze the data so that it will be reproducible in the future.
#
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# We recognize that the two main variables of our study, ICE arrests and criminal offenses per capita, are closely intertwined with historically discriminatory socio-economic factors. While the data may reflect systemic discriminatory bias, we do not believe the data itself is unfairly discriminatory. Our project works to analyze the hypothesized cross-over between two groups of people, those arrested by ICE and those who have committed a criminal offense.
#
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# As previously mentioned, we recognize that data regarding criminal offenses and ICE arrests exist within a socio-economic and political context. The criminal justice system disproportionately affects marginalized communities, which will be reflected in released datasets. As a group, we will analyze our findings with this in mind, knowing that the representation of people groups within the two categories of criminal offenses and ICE arrests are not reflective of a just system.
#
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Each group member should check in regularly and respond within a reasonable timeframe to ensure tasks are coordinated and questions are addressed quickly.*
# * *Every team member contributes meaningfully to all project phases and is accountable for completing assigned tasks on time. 2*
# * *All work should be committed to the team’s GitHub repository with clear commit messages, frequent commits, and proper branching (e.g., each feature on its own branch) to ensure version control and transparency among teammates. 3*
# * *Team members should treat each other with respect, be open to constructive feedback, and resolve differences through discussion and compromise to maintain a productive team environment.*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work
#
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/20  |  1 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/26  |  10 AM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 2/1  | 10 AM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/14  | 6 PM  | Import & Wrangle Data (Juan); EDA (Dylan) | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 2/23  | 12 PM  | Finalize wrangling/EDA; Begin Analysis (Russell; Sierra) | Discuss/edit Analysis; Complete project check-in |
# | 3/13  | 12 PM  | Complete analysis; Draft results/conclusion/discussion (Ellen)| Discuss/edit full project |
# | 3/20  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
